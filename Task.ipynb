# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'File.csv' with your file path
df1 = pd.read_csv("Task_file.csv", encoding="ISO-8859-1")

# %%
df1.head()
# Out:
#     Sr_no.   Crop_Name                                          Crop_Image   \
# 0       1.0       Potato  https://i.pinimg.com/236x/a3/8e/1f/a38e1fc2e9c...
# 1       2.0      Tomato   https://i.pinimg.com/236x/f4/d5/c9/f4d5c90b51c...
# 2       3.0        Wheat  https://i.pinimg.com/236x/f3/4e/49/f34e4922006...
# 3       4.0         Rice  https://i.pinimg.com/236x/f0/9a/fe/f09afefabdc...
# 4       5.0         Rose  https://i.pinimg.com/236x/1e/b2/16/1eb21609de2...
#
#      State                                            Crop_Plant_Image  \
# 0    Punjab          https://i.pinimg.com/236x/60/b8/55/60b855baa39...
# 1    Maharashtra     https://i.pinimg.com/236x/a6/67/b7/a667b778549...
# 2   Andhra Pradesh   https://i.pinimg.com/236x/8d/4a/7f/8d4a7f6cf71...
# 3    Punjab          https://i.pinimg.com/236x/57/10/c2/5710c2ddb1e...
# 4    Tamil Nadu      https://i.pinimg.com/236x/57/16/dd/5716dd7c1d6...
#
#     Date           Time      Health_Assessment   \
# ...

# %%
df2 = pd.read_csv("rainfall.csv", encoding="ISO-8859-1")

# %%
df2.head()
# Out:
#           Area  Year average_rain_fall_mm_per_year
# 0  Afghanistan  1985                           327
# 1  Afghanistan  1986                           327
# 2  Afghanistan  1987                           327
# 3  Afghanistan  1989                           327
# 4  Afghanistan  1990                           327
